# %% [markdown]
# # 모델별 학습

# %% [markdown]
# * 각 모델 실행 시 마다 커널을 재시작 해줍니다.

# %% [markdown]
# ## BSPM

# %%
import os
ROOT_PATH = os.getcwd()
RELATIVE_BSPM_PATH = "./BSPM/bspm"

# %%
# Root 작업 경로로 변경
os.chdir(ROOT_PATH)

# 현재 작업 경로 출력
print("현재 작업 경로:", os.getcwd())

# 상대 경로를 절대 경로로 변환
absolute_path = os.path.abspath(RELATIVE_BSPM_PATH)

# 작업 경로 변경
os.chdir(absolute_path)

# 변경된 작업 경로 출력
print("변경된 작업 경로:", os.getcwd())
# Out:
# 현재 작업 경로: C:\Users\medici\Dacon_Job-Recommendation-System
# 변경된 작업 경로: C:\Users\medici\Dacon_Job-Recommendation-System\BSPM\bspm

# %%
# %run main.py --dataset="JOB" --topks="[5]" --simple_model="bspm" --solver_shr="rk4" \
--K_s=1 --T_s=3.5 --final_sharpening=True --idl_beta=0.3 --factor_dim=960
# Out:
# ██████╗ ███████╗██████╗ ███╗   ███╗
# ██╔══██╗██╔════╝██╔══██╗████╗ ████║
# ██████╔╝███████╗██████╔╝██╔████╔██║
# ██╔══██╗╚════██║██╔═══╝ ██║╚██╔╝██║
# ██████╔╝███████║██║     ██║ ╚═╝ ██║
# ╚═════╝ ╚══════╝╚═╝     ╚═╝     ╚═╝
#
# Cpp extension not loaded
# >>SEED: 2020
# loading [../data/JOB]
# # of user: 8482
# # of item: 6695
# 57946 interactions for training
# 57946 interactions for testing
# JOB Sparsity : 0.0020408195609592974
# JOB is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'K_b': 1,
#  'K_idl': 1,
#  'K_s': 1,
#  'T_b': 1,
#  'T_idl': 1,
#  'T_s': 3.5,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'dataset': 'JOB',
#  'decay': 0.0001,
#  'device': device(type='cuda', index=0),
#  'dropout': 0,
#  'factor_dim': 960,
#  'final_sharpening': True,
#  'idl_beta': 0.3,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 64,
#  'lightGCN_n_layers': 3,
#  'lr': 0.001,
#  'multicore': 0,
#  'pretrain': 0,
#  'sharpening_off': False,
#  'solver_blr': 'euler',
#  'solver_idl': 'euler',
#  'solver_shr': 'rk4',
#  't_point_combination': False,
#  'test_u_batch_size': 100}
# cores for test: 6
# comment: lgn
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [5]
# using bpr loss
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# successfully loaded...
# don't split the matrix
# lgn is already to go(dropout:0)
# load and save to C:\Users\medici\Dacon_Job-Recommendation-System\BSPM\code\checkpoints\lgn-JOB-3-64.pth.tar
# [TEST]
# IDL: euler, BLR: euler, SHR: rk4
# IDL factor_dim:  960
# IDL $\beta$:  0.3
# idl time:  tensor([0., 1.])
# blur time:  tensor([0., 1.])
# sharpen time:  tensor([0.0000, 3.5000])
# final_sharpening:  True
# sharpening off:  False
# t_point_combination:  False
# training time for BSPM 347.97813606262207
# {'precision': array([0.]), 'recall': array([0.]), 'ndcg': array([0.])}

# %% [markdown]
# ## LT-OCF

# %%
os._exit(00)

# %%
import os
ROOT_PATH = os.getcwd()
RELATIVE_LTOCF_PATH = "./LT-OCF/code"

# %%
# Root 작업 경로로 변경
os.chdir(ROOT_PATH)

# 현재 작업 경로 출력
print("현재 작업 경로:", os.getcwd())

# 상대 경로를 절대 경로로 변환
absolute_path = os.path.abspath(RELATIVE_LTOCF_PATH)

# 작업 경로 변경
os.chdir(absolute_path)

# 변경된 작업 경로 출력
print("변경된 작업 경로:", os.getcwd())
# Out:
# 현재 작업 경로: C:\Users\medici\Dacon_Job-Recommendation-System
# 변경된 작업 경로: C:\Users\medici\Dacon_Job-Recommendation-System\LT-OCF\code

# %%
# %run main.py --dataset="JOB" --model="ltocf" --solver="rk4" --adjoint=False \
--K=4 --learnable_time=False --dual_res=False --lr=1e-3 --lr_time=1e-3 \
--decay=1e-4 --topks="[5]" --tensorboard=1 --gpuid=0 \
--epochs=320 --layer=2 --recdim=360 --bpr_batch=2048 --pretrain=0
# Out:
# 현재 사용 중인 GPU 디바이스: NVIDIA GeForce RTX 2070
#
# ██╗  ████████╗    ██████╗  ██████╗███████╗
# ██║  ╚══██╔══╝   ██╔═══██╗██╔════╝██╔════╝
# ██║     ██║█████╗██║   ██║██║     █████╗
# ██║     ██║╚════╝██║   ██║██║     ██╔══╝
# ███████╗██║      ╚██████╔╝╚██████╗██║
# ╚══════╝╚═╝       ╚═════╝  ╚═════╝╚═╝
#
# Current cuda device  0
# >>SEED: 2020
# loading [../data/JOB]
# 57946 interactions for training
# 57946 interactions for testing
# JOB Sparsity : 0.0020408195609592974
# JOB is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'K': 4.0,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'dual_res': False,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 360,
#  'learnable_time': False,
#  'lightGCN_n_layers': 2,
#  'lr': 0.001,
#  'lr_time': 0.001,
#  'multicore': 0,
#  'pretrain': 0,
#  'pretrained_file_name': 'ltocf',
#  'solver': 'rk4',
#  'test_u_batch_size': 512,
#  'time_split': 4}
# cores for test: 6
# comment: lt-ncf
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [5]
# using bpr loss
# adjoint method: False
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# successfully loaded...
# don't split the matrix
# lgn is already to go(dropout:0)
# load and save to C:\Users\medici\Dacon_Job-Recommendation-System\LT-OCF\code\pretrain\ltocf
# Train time: 2.4618s
# EPOCH[1/320] ('loss0.48436-|Sample:0.00|', 0.48435897946357725)
# Train time: 2.2550s
# EPOCH[2/320] ('loss0.21276-|Sample:0.01|', 0.21275581538677216)
# Train time: 2.2543s
# EPOCH[3/320] ('loss0.12019-|Sample:0.01|', 0.1201887884736061)
# Train time: 2.2281s
# EPOCH[4/320] ('loss0.08870-|Sample:0.01|', 0.0886970180273056)
# Train time: 2.2453s
# EPOCH[5/320] ('loss0.07577-|Sample:0.02|', 0.07577136009931565)
# Train time: 2.2335s
# EPOCH[6/320] ('loss0.06049-|Sample:0.00|', 0.060489084869623184)
# Train time: 2.2531s
# EPOCH[7/320] ('loss0.05630-|Sample:0.02|', 0.056301176249980926)
# Train time: 2.2492s
# EPOCH[8/320] ('loss0.05059-|Sample:0.02|', 0.05058604940772057)
# Train time: 2.2498s
# EPOCH[9/320] ('loss0.04506-|Sample:0.02|', 0.04506228655576706)
# Train time: 2.2665s
# EPOCH[10/320] ('loss0.04100-|Sample:0.00|', 0.0409984190762043)
# Train time: 2.2535s
# EPOCH[11/320] ('loss0.03979-|Sample:0.00|', 0.039785194247961043)
# Train time: 2.2616s
# EPOCH[12/320] ('loss0.03786-|Sample:0.02|', 0.03786430239677429)
# Train time: 2.2659s
# EPOCH[13/320] ('loss0.03568-|Sample:0.02|', 0.03568224839866161)
# Train time: 2.2702s
# EPOCH[14/320] ('loss0.03213-|Sample:0.00|', 0.03212520204484463)
# Train time: 2.2627s
# EPOCH[15/320] ('loss0.03039-|Sample:0.02|', 0.03039292611181736)
# Train time: 2.2630s
# EPOCH[16/320] ('loss0.02917-|Sample:0.02|', 0.02917462058365345)
# Train time: 2.2563s
# EPOCH[17/320] ('loss0.02764-|Sample:0.00|', 0.027637907937169075)
# Train time: 2.2950s
# EPOCH[18/320] ('loss0.02734-|Sample:0.02|', 0.027335408553481103)
# Train time: 2.3317s
# EPOCH[19/320] ('loss0.02599-|Sample:0.00|', 0.025992529466748238)
# Train time: 2.3552s
# EPOCH[20/320] ('loss0.02401-|Sample:0.01|', 0.024009873755276204)
# Train time: 2.3283s
# EPOCH[21/320] ('loss0.02414-|Sample:0.01|', 0.024135743975639345)
# Train time: 2.2885s
# EPOCH[22/320] ('loss0.02211-|Sample:0.01|', 0.022113450765609742)
# Train time: 2.3440s
# EPOCH[23/320] ('loss0.02170-|Sample:0.02|', 0.021700881980359556)
# Train time: 2.3250s
# EPOCH[24/320] ('loss0.02178-|Sample:0.01|', 0.021781452149152756)
# Train time: 2.2869s
# EPOCH[25/320] ('loss0.02096-|Sample:0.01|', 0.020958555340766908)
# Train time: 2.3154s
# EPOCH[26/320] ('loss0.01938-|Sample:0.00|', 0.019375299923121928)
# Train time: 2.3745s
# EPOCH[27/320] ('loss0.01985-|Sample:0.01|', 0.019851503260433674)
# Train time: 2.3345s
# EPOCH[28/320] ('loss0.01927-|Sample:0.02|', 0.01927199274301529)
# Train time: 2.4319s
# EPOCH[29/320] ('loss0.01762-|Sample:0.02|', 0.01762398563325405)
# Train time: 2.4380s
# EPOCH[30/320] ('loss0.01781-|Sample:0.02|', 0.017814282663166522)
# Train time: 2.4725s
# EPOCH[31/320] ('loss0.01602-|Sample:0.02|', 0.016020781621336938)
# Train time: 2.3569s
# EPOCH[32/320] ('loss0.01631-|Sample:0.02|', 0.01630984991788864)
# Train time: 2.2876s
# EPOCH[33/320] ('loss0.01750-|Sample:0.02|', 0.017497424706816672)
# Train time: 2.2846s
# EPOCH[34/320] ('loss0.01621-|Sample:0.02|', 0.016212990172207356)
# Train time: 2.2907s
# EPOCH[35/320] ('loss0.01527-|Sample:0.00|', 0.015265493094921112)
# Train time: 2.2898s
# EPOCH[36/320] ('loss0.01633-|Sample:0.02|', 0.016331859193742276)
# Train time: 2.2838s
# EPOCH[37/320] ('loss0.01531-|Sample:0.00|', 0.015308074131608009)
# Train time: 2.2841s
# EPOCH[38/320] ('loss0.01464-|Sample:0.02|', 0.014639775790274144)
# Train time: 2.2847s
# EPOCH[39/320] ('loss0.01448-|Sample:0.02|', 0.014479032531380654)
# Train time: 2.2858s
# EPOCH[40/320] ('loss0.01436-|Sample:0.02|', 0.014358954615890979)
# Train time: 2.2875s
# EPOCH[41/320] ('loss0.01399-|Sample:0.00|', 0.013987738639116287)
# Train time: 2.2832s
# EPOCH[42/320] ('loss0.01300-|Sample:0.02|', 0.012997434698045254)
# Train time: 2.3025s
# EPOCH[43/320] ('loss0.01294-|Sample:0.02|', 0.012942017577588559)
# Train time: 2.2925s
# EPOCH[44/320] ('loss0.01221-|Sample:0.02|', 0.012205905057489872)
# Train time: 2.2899s
# EPOCH[45/320] ('loss0.01292-|Sample:0.02|', 0.012922758907079697)
# Train time: 2.2864s
# EPOCH[46/320] ('loss0.01240-|Sample:0.02|', 0.012401915229856968)
# Train time: 2.2883s
# EPOCH[47/320] ('loss0.01275-|Sample:0.00|', 0.012746291495859622)
# Train time: 2.2913s
# EPOCH[48/320] ('loss0.01193-|Sample:0.02|', 0.011928997673094273)
# Train time: 2.2871s
# EPOCH[49/320] ('loss0.01104-|Sample:0.02|', 0.011040588617324829)
# Train time: 2.2867s
# EPOCH[50/320] ('loss0.01153-|Sample:0.02|', 0.011534673217684031)
# Train time: 2.2755s
# EPOCH[51/320] ('loss0.01179-|Sample:0.02|', 0.011789184734225274)
# Train time: 2.2821s
# EPOCH[52/320] ('loss0.01195-|Sample:0.01|', 0.011947279311716557)
# Train time: 2.2875s
# EPOCH[53/320] ('loss0.01012-|Sample:0.02|', 0.010118718352168798)
# Train time: 2.2917s
# EPOCH[54/320] ('loss0.01094-|Sample:0.02|', 0.010938490852713584)
# Train time: 2.2767s
# EPOCH[55/320] ('loss0.01167-|Sample:0.00|', 0.011667026616632938)
# Train time: 2.2934s
# EPOCH[56/320] ('loss0.01040-|Sample:0.00|', 0.010402301270514726)
# Train time: 2.2876s
# EPOCH[57/320] ('loss0.01019-|Sample:0.02|', 0.010193674135953188)
# Train time: 2.2810s
# EPOCH[58/320] ('loss0.01012-|Sample:0.00|', 0.010115799363702535)
# Train time: 2.2813s
# EPOCH[59/320] ('loss0.00911-|Sample:0.02|', 0.009111886601895094)
# Train time: 2.2838s
# EPOCH[60/320] ('loss0.00970-|Sample:0.00|', 0.009703112784773111)
# Train time: 2.2784s
# EPOCH[61/320] ('loss0.00935-|Sample:0.02|', 0.009349186066538095)
# Train time: 2.2856s
# EPOCH[62/320] ('loss0.00907-|Sample:0.02|', 0.009071444123983384)
# Train time: 2.2845s
# EPOCH[63/320] ('loss0.00891-|Sample:0.02|', 0.008913575280457735)
# Train time: 2.2876s
# EPOCH[64/320] ('loss0.00895-|Sample:0.02|', 0.008949275631457566)
# Train time: 2.2575s
# EPOCH[65/320] ('loss0.00889-|Sample:0.02|', 0.0088899128139019)
# Train time: 2.3117s
# EPOCH[66/320] ('loss0.00919-|Sample:0.02|', 0.009190693926066161)
# Train time: 2.3155s
# EPOCH[67/320] ('loss0.00929-|Sample:0.01|', 0.009289576336741448)
# Train time: 2.2745s
# EPOCH[68/320] ('loss0.00922-|Sample:0.01|', 0.009223380163311957)
# Train time: 2.3277s
# EPOCH[69/320] ('loss0.00918-|Sample:0.01|', 0.00918167607858777)
# Train time: 2.3204s
# EPOCH[70/320] ('loss0.00863-|Sample:0.02|', 0.008630931694060564)
# Train time: 2.3044s
# EPOCH[71/320] ('loss0.00837-|Sample:0.02|', 0.008369845394045115)
# Train time: 2.2687s
# EPOCH[72/320] ('loss0.00806-|Sample:0.00|', 0.008060369305312634)
# Train time: 2.2667s
# EPOCH[73/320] ('loss0.00840-|Sample:0.02|', 0.008404501248151064)
# Train time: 2.2987s
# EPOCH[74/320] ('loss0.00861-|Sample:0.00|', 0.008607812337577342)
# Train time: 2.2718s
# EPOCH[75/320] ('loss0.00792-|Sample:0.02|', 0.007920373771339655)
# Train time: 2.2659s
# EPOCH[76/320] ('loss0.00764-|Sample:0.00|', 0.007642135489732027)
# Train time: 2.2702s
# EPOCH[77/320] ('loss0.00875-|Sample:0.00|', 0.00874927882105112)
# Train time: 2.2628s
# EPOCH[78/320] ('loss0.00813-|Sample:0.02|', 0.008131618406623601)
# Train time: 2.2665s
# EPOCH[79/320] ('loss0.00778-|Sample:0.02|', 0.007780688907951116)
# Train time: 2.2876s
# EPOCH[80/320] ('loss0.00745-|Sample:0.02|', 0.007447373401373625)
# Train time: 2.2857s
# EPOCH[81/320] ('loss0.00784-|Sample:0.02|', 0.007842770535498858)
# Train time: 2.2822s
# EPOCH[82/320] ('loss0.00790-|Sample:0.02|', 0.007900599744170905)
# Train time: 2.2793s
# EPOCH[83/320] ('loss0.00737-|Sample:0.02|', 0.0073731947503983975)
# Train time: 2.2791s
# EPOCH[84/320] ('loss0.00769-|Sample:0.02|', 0.007692297082394361)
# Train time: 2.2752s
# EPOCH[85/320] ('loss0.00773-|Sample:0.02|', 0.007728760261088609)
# Train time: 2.2703s
# EPOCH[86/320] ('loss0.00737-|Sample:0.00|', 0.007371655032038689)
# Train time: 2.2493s
# EPOCH[87/320] ('loss0.00671-|Sample:0.02|', 0.006709150820970535)
# Train time: 2.3001s
# EPOCH[88/320] ('loss0.00726-|Sample:0.02|', 0.007263918407261372)
# Train time: 2.3213s
# EPOCH[89/320] ('loss0.00621-|Sample:0.01|', 0.006213262844830751)
# Train time: 2.3174s
# EPOCH[90/320] ('loss0.00720-|Sample:0.01|', 0.007204047478735447)
# Train time: 2.3117s
# EPOCH[91/320] ('loss0.00727-|Sample:0.02|', 0.0072703780047595505)
# Train time: 2.3013s
# EPOCH[92/320] ('loss0.00732-|Sample:0.00|', 0.007315497035160661)
# Train time: 2.3309s
# EPOCH[93/320] ('loss0.00656-|Sample:0.01|', 0.006555063761770725)
# Train time: 2.3122s
# EPOCH[94/320] ('loss0.00716-|Sample:0.01|', 0.0071641226019710305)
# Train time: 2.2911s
# EPOCH[95/320] ('loss0.00702-|Sample:0.00|', 0.00701514083892107)
# Train time: 2.2889s
# EPOCH[96/320] ('loss0.00680-|Sample:0.00|', 0.006797384759411215)
# Train time: 2.3061s
# EPOCH[97/320] ('loss0.00648-|Sample:0.01|', 0.0064783629775047305)
# Train time: 2.3127s
# EPOCH[98/320] ('loss0.00624-|Sample:0.00|', 0.006237095035612583)
# Train time: 2.2900s
# EPOCH[99/320] ('loss0.00689-|Sample:0.02|', 0.006894007325172424)
# Train time: 2.2973s
# EPOCH[100/320] ('loss0.00605-|Sample:0.00|', 0.006049954518675804)
# Train time: 2.3077s
# EPOCH[101/320] ('loss0.00629-|Sample:0.02|', 0.006289206109941005)
# Train time: 2.2960s
# EPOCH[102/320] ('loss0.00703-|Sample:0.00|', 0.007031099535524845)
# Train time: 2.3065s
# EPOCH[103/320] ('loss0.00649-|Sample:0.00|', 0.006491252835839987)
# Train time: 2.2931s
# EPOCH[104/320] ('loss0.00586-|Sample:0.02|', 0.005860160114243626)
# Train time: 2.2852s
# EPOCH[105/320] ('loss0.00597-|Sample:0.02|', 0.005970563050359487)
# Train time: 2.2838s
# EPOCH[106/320] ('loss0.00587-|Sample:0.02|', 0.005873940959572792)
# Train time: 2.2859s
# EPOCH[107/320] ('loss0.00642-|Sample:0.00|', 0.006422691289335489)
# Train time: 2.2816s
# EPOCH[108/320] ('loss0.00587-|Sample:0.02|', 0.00587277403101325)
# Train time: 2.2934s
# EPOCH[109/320] ('loss0.00597-|Sample:0.00|', 0.0059721445851027965)
# Train time: 2.2917s
# EPOCH[110/320] ('loss0.00539-|Sample:0.02|', 0.00539284685626626)
# Train time: 2.2886s
# EPOCH[111/320] ('loss0.00609-|Sample:0.02|', 0.006092792265117168)
# Train time: 2.2896s
# EPOCH[112/320] ('loss0.00640-|Sample:0.00|', 0.006396413743495941)
# Train time: 2.2856s
# EPOCH[113/320] ('loss0.00549-|Sample:0.02|', 0.005489829583093524)
# Train time: 2.2884s
# EPOCH[114/320] ('loss0.00638-|Sample:0.02|', 0.006380360648036003)
# Train time: 2.2770s
# EPOCH[115/320] ('loss0.00593-|Sample:0.02|', 0.00593348503112793)
# Train time: 2.3335s
# EPOCH[116/320] ('loss0.00582-|Sample:0.02|', 0.005822753086686134)
# Train time: 2.2886s
# EPOCH[117/320] ('loss0.00564-|Sample:0.01|', 0.005642482256516815)
# Train time: 2.2718s
# EPOCH[118/320] ('loss0.00514-|Sample:0.02|', 0.005140091702342034)
# Train time: 2.3040s
# EPOCH[119/320] ('loss0.00528-|Sample:0.02|', 0.00527544854208827)
# Train time: 2.2826s
# EPOCH[120/320] ('loss0.00517-|Sample:0.02|', 0.0051701459102332595)
# Train time: 2.2591s
# EPOCH[121/320] ('loss0.00595-|Sample:0.02|', 0.005954405777156353)
# Train time: 2.2815s
# EPOCH[122/320] ('loss0.00505-|Sample:0.02|', 0.005052927900105714)
# Train time: 2.2798s
# EPOCH[123/320] ('loss0.00500-|Sample:0.00|', 0.004997632158920169)
# Train time: 2.2726s
# EPOCH[124/320] ('loss0.00557-|Sample:0.02|', 0.0055709015019238)
# Train time: 2.2771s
# EPOCH[125/320] ('loss0.00553-|Sample:0.02|', 0.005531699573621154)
# Train time: 2.2758s
# EPOCH[126/320] ('loss0.00532-|Sample:0.00|', 0.0053154796548187735)
# Train time: 2.2807s
# EPOCH[127/320] ('loss0.00523-|Sample:0.00|', 0.005226760925725102)
# Train time: 2.3033s
# EPOCH[128/320] ('loss0.00563-|Sample:0.01|', 0.0056307496875524525)
# Train time: 2.3283s
# EPOCH[129/320] ('loss0.00595-|Sample:0.01|', 0.005947932563722134)
# Train time: 2.3067s
# EPOCH[130/320] ('loss0.00529-|Sample:0.01|', 0.005288585349917412)
# Train time: 2.2872s
# EPOCH[131/320] ('loss0.00541-|Sample:0.02|', 0.005409965422004461)
# Train time: 2.2964s
# EPOCH[132/320] ('loss0.00555-|Sample:0.01|', 0.005553365293890238)
# Train time: 2.2933s
# EPOCH[133/320] ('loss0.00529-|Sample:0.00|', 0.005287208529189229)
# Train time: 2.2868s
# EPOCH[134/320] ('loss0.00540-|Sample:0.02|', 0.005396033218130469)
# Train time: 2.2857s
# EPOCH[135/320] ('loss0.00524-|Sample:0.02|', 0.005243608169257641)
# Train time: 2.2823s
# EPOCH[136/320] ('loss0.00512-|Sample:0.02|', 0.005124164158478379)
# Train time: 2.2888s
# EPOCH[137/320] ('loss0.00534-|Sample:0.02|', 0.0053396091517060994)
# Train time: 2.2894s
# EPOCH[138/320] ('loss0.00476-|Sample:0.00|', 0.004762740563601256)
# Train time: 2.2871s
# EPOCH[139/320] ('loss0.00472-|Sample:0.02|', 0.004721782952547073)
# Train time: 2.2817s
# EPOCH[140/320] ('loss0.00495-|Sample:0.02|', 0.004946332741528749)
# Train time: 2.2870s
# EPOCH[141/320] ('loss0.00489-|Sample:0.00|', 0.004894486078992486)
# Train time: 2.2891s
# EPOCH[142/320] ('loss0.00474-|Sample:0.02|', 0.004736082535237074)
# Train time: 2.2846s
# EPOCH[143/320] ('loss0.00492-|Sample:0.02|', 0.004918493572622537)
# Train time: 2.2834s
# EPOCH[144/320] ('loss0.00476-|Sample:0.02|', 0.004763815458863974)
# Train time: 2.2955s
# EPOCH[145/320] ('loss0.00488-|Sample:0.00|', 0.004876039391383528)
# Train time: 2.2849s
# EPOCH[146/320] ('loss0.00502-|Sample:0.00|', 0.005021942220628262)
# Train time: 2.2784s
# EPOCH[147/320] ('loss0.00509-|Sample:0.02|', 0.00508859253488481)
# Train time: 2.2844s
# EPOCH[148/320] ('loss0.00485-|Sample:0.00|', 0.004849373269826174)
# Train time: 2.2854s
# EPOCH[149/320] ('loss0.00486-|Sample:0.00|', 0.004861339787021279)
# Train time: 2.2865s
# EPOCH[150/320] ('loss0.00505-|Sample:0.02|', 0.005049499114975333)
# Train time: 2.2893s
# EPOCH[151/320] ('loss0.00483-|Sample:0.01|', 0.004829560033977031)
# Train time: 2.3213s
# EPOCH[152/320] ('loss0.00460-|Sample:0.01|', 0.004599605305120349)
# Train time: 2.2849s
# EPOCH[153/320] ('loss0.00531-|Sample:0.00|', 0.005314846187829971)
# Train time: 2.2946s
# EPOCH[154/320] ('loss0.00454-|Sample:0.02|', 0.004544827630743384)
# Train time: 2.2881s
# EPOCH[155/320] ('loss0.00493-|Sample:0.02|', 0.004930676501244307)
# Train time: 2.2909s
# EPOCH[156/320] ('loss0.00503-|Sample:0.02|', 0.005028294380754233)
# Train time: 2.2897s
# EPOCH[157/320] ('loss0.00453-|Sample:0.02|', 0.004528691926971078)
# Train time: 2.2947s
# EPOCH[158/320] ('loss0.00458-|Sample:0.01|', 0.004584133727476001)
# Train time: 2.2895s
# EPOCH[159/320] ('loss0.00446-|Sample:0.02|', 0.004464563876390457)
# Train time: 2.2915s
# EPOCH[160/320] ('loss0.00460-|Sample:0.00|', 0.004596170503646135)
# Train time: 2.3166s
# EPOCH[161/320] ('loss0.00450-|Sample:0.02|', 0.004499806510284543)
# Train time: 2.3292s
# EPOCH[162/320] ('loss0.00436-|Sample:0.02|', 0.004358552731573582)
# Train time: 2.2977s
# EPOCH[163/320] ('loss0.00471-|Sample:0.02|', 0.0047116581443697216)
# Train time: 2.3053s
# EPOCH[164/320] ('loss0.00464-|Sample:0.00|', 0.00463747413828969)
# Train time: 2.2866s
# EPOCH[165/320] ('loss0.00496-|Sample:0.02|', 0.004958583749830723)
# Train time: 2.2901s
# EPOCH[166/320] ('loss0.00460-|Sample:0.02|', 0.00460440345108509)
# Train time: 2.2882s
# EPOCH[167/320] ('loss0.00478-|Sample:0.00|', 0.004784225625917316)
# Train time: 2.2745s
# EPOCH[168/320] ('loss0.00430-|Sample:0.02|', 0.0042985320836305616)
# Train time: 2.2702s
# EPOCH[169/320] ('loss0.00473-|Sample:0.02|', 0.004725083885714412)
# Train time: 2.2873s
# EPOCH[170/320] ('loss0.00437-|Sample:0.02|', 0.004373315703123808)
# Train time: 2.2834s
# EPOCH[171/320] ('loss0.00466-|Sample:0.00|', 0.004657622622326016)
# Train time: 2.2855s
# EPOCH[172/320] ('loss0.00427-|Sample:0.00|', 0.004269597744569182)
# Train time: 2.2728s
# EPOCH[173/320] ('loss0.00408-|Sample:0.02|', 0.00407771940343082)
# Train time: 2.2611s
# EPOCH[174/320] ('loss0.00451-|Sample:0.02|', 0.0045069596823304895)
# Train time: 2.2986s
# EPOCH[175/320] ('loss0.00442-|Sample:0.01|', 0.004420668827369809)
# Train time: 2.2935s
# EPOCH[176/320] ('loss0.00417-|Sample:0.01|', 0.00417374286800623)
# Train time: 2.2902s
# EPOCH[177/320] ('loss0.00436-|Sample:0.02|', 0.004361837236210704)
# Train time: 2.2620s
# EPOCH[178/320] ('loss0.00453-|Sample:0.02|', 0.004531593723222613)
# Train time: 2.2737s
# EPOCH[179/320] ('loss0.00442-|Sample:0.00|', 0.004419168457388878)
# Train time: 2.2707s
# EPOCH[180/320] ('loss0.00394-|Sample:0.01|', 0.003937413189560175)
# Train time: 2.2887s
# EPOCH[181/320] ('loss0.00428-|Sample:0.00|', 0.004284081151708961)
# Train time: 2.2725s
# EPOCH[182/320] ('loss0.00418-|Sample:0.00|', 0.004175136024132371)
# Train time: 2.2681s
# EPOCH[183/320] ('loss0.00391-|Sample:0.00|', 0.0039087868295609954)
# Train time: 2.2786s
# EPOCH[184/320] ('loss0.00417-|Sample:0.00|', 0.004171222122386098)
# Train time: 2.2871s
# EPOCH[185/320] ('loss0.00406-|Sample:0.00|', 0.0040591307170689105)
# Train time: 2.2829s
# EPOCH[186/320] ('loss0.00403-|Sample:0.00|', 0.004029991338029504)
# Train time: 2.2861s
# EPOCH[187/320] ('loss0.00414-|Sample:0.00|', 0.004136893833056092)
# Train time: 2.2928s
# EPOCH[188/320] ('loss0.00428-|Sample:0.02|', 0.004276787806302309)
# Train time: 2.2862s
# EPOCH[189/320] ('loss0.00416-|Sample:0.02|', 0.004160557659342885)
# Train time: 2.2855s
# EPOCH[190/320] ('loss0.00454-|Sample:0.02|', 0.0045350516680628065)
# Train time: 2.2893s
# EPOCH[191/320] ('loss0.00421-|Sample:0.02|', 0.0042101956065744165)
# Train time: 2.2873s
# EPOCH[192/320] ('loss0.00426-|Sample:0.02|', 0.004259720398113132)
# Train time: 2.2705s
# EPOCH[193/320] ('loss0.00405-|Sample:0.01|', 0.004053478259593248)
# Train time: 2.2654s
# EPOCH[194/320] ('loss0.00420-|Sample:0.02|', 0.0042006361670792105)
# Train time: 2.2851s
# EPOCH[195/320] ('loss0.00437-|Sample:0.01|', 0.004371007243171334)
# Train time: 2.2853s
# EPOCH[196/320] ('loss0.00428-|Sample:0.02|', 0.004276464339345694)
# Train time: 2.2841s
# EPOCH[197/320] ('loss0.00365-|Sample:0.00|', 0.00365299797616899)
# Train time: 2.2868s
# EPOCH[198/320] ('loss0.00417-|Sample:0.00|', 0.004173449464142323)
# Train time: 2.3402s
# EPOCH[199/320] ('loss0.00412-|Sample:0.00|', 0.004117347281426192)
# Train time: 2.3255s
# EPOCH[200/320] ('loss0.00426-|Sample:0.00|', 0.004255077242851258)
# Train time: 2.3179s
# EPOCH[201/320] ('loss0.00391-|Sample:0.01|', 0.00391023674979806)
# Train time: 2.3188s
# EPOCH[202/320] ('loss0.00397-|Sample:0.01|', 0.003974722381681204)
# Train time: 2.2982s
# EPOCH[203/320] ('loss0.00427-|Sample:0.02|', 0.004274484571069479)
# Train time: 2.2996s
# EPOCH[204/320] ('loss0.00439-|Sample:0.02|', 0.0043890923820436)
# Train time: 2.3005s
# EPOCH[205/320] ('loss0.00388-|Sample:0.00|', 0.0038792237360030413)
# Train time: 2.2962s
# EPOCH[206/320] ('loss0.00419-|Sample:0.00|', 0.00419469004496932)
# Train time: 2.2962s
# EPOCH[207/320] ('loss0.00373-|Sample:0.02|', 0.0037266032677143813)
# Train time: 2.3026s
# EPOCH[208/320] ('loss0.00384-|Sample:0.02|', 0.0038399766758084298)
# Train time: 2.3009s
# EPOCH[209/320] ('loss0.00447-|Sample:0.00|', 0.004469453813508153)
# Train time: 2.2999s
# EPOCH[210/320] ('loss0.00393-|Sample:0.02|', 0.0039323840010911226)
# Train time: 2.3019s
# EPOCH[211/320] ('loss0.00406-|Sample:0.00|', 0.0040633902139961715)
# Train time: 2.2970s
# EPOCH[212/320] ('loss0.00375-|Sample:0.00|', 0.0037472498510032893)
# Train time: 2.2955s
# EPOCH[213/320] ('loss0.00373-|Sample:0.02|', 0.0037273185793310405)
# Train time: 2.2909s
# EPOCH[214/320] ('loss0.00394-|Sample:0.00|', 0.003943131007254123)
# Train time: 2.3020s
# EPOCH[215/320] ('loss0.00387-|Sample:0.02|', 0.0038719841931015254)
# Train time: 2.3113s
# EPOCH[216/320] ('loss0.00366-|Sample:0.02|', 0.003663632646203041)
# Train time: 2.2953s
# EPOCH[217/320] ('loss0.00416-|Sample:0.02|', 0.004158617127686739)
# Train time: 2.2997s
# EPOCH[218/320] ('loss0.00380-|Sample:0.00|', 0.0038037221133708954)
# Train time: 2.3046s
# EPOCH[219/320] ('loss0.00384-|Sample:0.00|', 0.0038416633754968644)
# Train time: 2.2979s
# EPOCH[220/320] ('loss0.00394-|Sample:0.02|', 0.003935227962210774)
# Train time: 2.2965s
# EPOCH[221/320] ('loss0.00384-|Sample:0.02|', 0.0038396805711090566)
# Train time: 2.2995s
# EPOCH[222/320] ('loss0.00407-|Sample:0.02|', 0.004066227301955223)
# Train time: 2.3168s
# EPOCH[223/320] ('loss0.00382-|Sample:0.02|', 0.0038203362375497816)
# Train time: 2.3556s
# EPOCH[224/320] ('loss0.00403-|Sample:0.01|', 0.004034083355218172)
# Train time: 2.3361s
# EPOCH[225/320] ('loss0.00373-|Sample:0.01|', 0.0037271245196461677)
# Train time: 2.2943s
# EPOCH[226/320] ('loss0.00397-|Sample:0.01|', 0.003967623589560389)
# Train time: 2.2875s
# EPOCH[227/320] ('loss0.00363-|Sample:0.02|', 0.003626573458313942)
# Train time: 2.2790s
# EPOCH[228/320] ('loss0.00371-|Sample:0.02|', 0.003712122505530715)
# Train time: 2.2630s
# EPOCH[229/320] ('loss0.00384-|Sample:0.02|', 0.003837392749264836)
# Train time: 2.2829s
# EPOCH[230/320] ('loss0.00343-|Sample:0.02|', 0.0034341449290513993)
# Train time: 2.2827s
# EPOCH[231/320] ('loss0.00379-|Sample:0.02|', 0.003788508316501975)
# Train time: 2.2730s
# EPOCH[232/320] ('loss0.00385-|Sample:0.00|', 0.003845583517104387)
# Train time: 2.2668s
# EPOCH[233/320] ('loss0.00366-|Sample:0.00|', 0.0036593573540449143)
# Train time: 2.3196s
# EPOCH[234/320] ('loss0.00404-|Sample:0.02|', 0.004037958756089211)
# Train time: 2.3094s
# EPOCH[235/320] ('loss0.00382-|Sample:0.01|', 0.003820897052064538)
# Train time: 2.3351s
# EPOCH[236/320] ('loss0.00352-|Sample:0.02|', 0.0035247118398547173)
# Train time: 2.3006s
# EPOCH[237/320] ('loss0.00379-|Sample:0.01|', 0.003787288051098585)
# Train time: 2.3256s
# EPOCH[238/320] ('loss0.00343-|Sample:0.00|', 0.0034294153563678266)
# Train time: 2.3170s
# EPOCH[239/320] ('loss0.00404-|Sample:0.01|', 0.004039778336882591)
# Train time: 2.3307s
# EPOCH[240/320] ('loss0.00341-|Sample:0.02|', 0.003406618982553482)
# Train time: 2.3136s
# EPOCH[241/320] ('loss0.00353-|Sample:0.01|', 0.003531062304973602)
# Train time: 2.2947s
# EPOCH[242/320] ('loss0.00376-|Sample:0.02|', 0.003764281366020441)
# Train time: 2.3331s
# EPOCH[243/320] ('loss0.00402-|Sample:0.01|', 0.004015904739499092)
# Train time: 2.3199s
# EPOCH[244/320] ('loss0.00377-|Sample:0.02|', 0.003772073481231928)
# Train time: 2.3217s
# EPOCH[245/320] ('loss0.00393-|Sample:0.01|', 0.003925811406224966)
# Train time: 2.2878s
# EPOCH[246/320] ('loss0.00357-|Sample:0.00|', 0.003566219424828887)
# Train time: 2.2888s
# EPOCH[247/320] ('loss0.00367-|Sample:0.02|', 0.003671317221596837)
# Train time: 2.2867s
# EPOCH[248/320] ('loss0.00338-|Sample:0.02|', 0.0033778299950063227)
# Train time: 2.3234s
# EPOCH[249/320] ('loss0.00334-|Sample:0.02|', 0.003343201857060194)
# Train time: 2.2849s
# EPOCH[250/320] ('loss0.00353-|Sample:0.02|', 0.0035345761477947237)
# Train time: 2.3001s
# EPOCH[251/320] ('loss0.00388-|Sample:0.02|', 0.0038778229523450136)
# Train time: 2.2905s
# EPOCH[252/320] ('loss0.00351-|Sample:0.02|', 0.003510347018018365)
# Train time: 2.2990s
# EPOCH[253/320] ('loss0.00359-|Sample:0.01|', 0.003586270771920681)
# Train time: 2.2897s
# EPOCH[254/320] ('loss0.00340-|Sample:0.02|', 0.003398869754746556)
# Train time: 2.2995s
# EPOCH[255/320] ('loss0.00347-|Sample:0.01|', 0.0034655632451176645)
# Train time: 2.2807s
# EPOCH[256/320] ('loss0.00393-|Sample:0.02|', 0.0039341973327100275)
# Train time: 2.2885s
# EPOCH[257/320] ('loss0.00348-|Sample:0.02|', 0.0034828978404402734)
# Train time: 2.3026s
# EPOCH[258/320] ('loss0.00369-|Sample:0.00|', 0.0036920762062072755)
# Train time: 2.2641s
# EPOCH[259/320] ('loss0.00337-|Sample:0.00|', 0.0033666211646050217)
# Train time: 2.2828s
# EPOCH[260/320] ('loss0.00393-|Sample:0.00|', 0.003925875714048743)
# Train time: 2.2892s
# EPOCH[261/320] ('loss0.00363-|Sample:0.00|', 0.0036315345671027897)
# Train time: 2.2931s
# EPOCH[262/320] ('loss0.00375-|Sample:0.02|', 0.0037450333684682846)
# Train time: 2.2868s
# EPOCH[263/320] ('loss0.00348-|Sample:0.02|', 0.0034810142312198876)
# Train time: 2.2762s
# EPOCH[264/320] ('loss0.00359-|Sample:0.02|', 0.003592215534299612)
# Train time: 2.2875s
# EPOCH[265/320] ('loss0.00347-|Sample:0.02|', 0.003469265662133694)
# Train time: 2.2877s
# EPOCH[266/320] ('loss0.00362-|Sample:0.00|', 0.0036245700903236866)
# Train time: 2.2911s
# EPOCH[267/320] ('loss0.00347-|Sample:0.00|', 0.003466060841456056)
# Train time: 2.2961s
# EPOCH[268/320] ('loss0.00367-|Sample:0.02|', 0.0036724977102130653)
# Train time: 2.2871s
# EPOCH[269/320] ('loss0.00359-|Sample:0.00|', 0.0035883596539497374)
# Train time: 2.2912s
# EPOCH[270/320] ('loss0.00318-|Sample:0.00|', 0.0031781770940870046)
# Train time: 2.3047s
# EPOCH[271/320] ('loss0.00320-|Sample:0.02|', 0.003195624528452754)
# Train time: 2.2965s
# EPOCH[272/320] ('loss0.00336-|Sample:0.01|', 0.0033646352495998143)
# Train time: 2.3522s
# EPOCH[273/320] ('loss0.00331-|Sample:0.02|', 0.0033084724377840757)
# Train time: 2.3954s
# EPOCH[274/320] ('loss0.00320-|Sample:0.00|', 0.003199359579011798)
# Train time: 2.2919s
# EPOCH[275/320] ('loss0.00343-|Sample:0.01|', 0.0034317018929868937)
# Train time: 2.2736s
# EPOCH[276/320] ('loss0.00343-|Sample:0.01|', 0.0034300603158771994)
# Train time: 2.2884s
# EPOCH[277/320] ('loss0.00359-|Sample:0.01|', 0.0035890243295580147)
# Train time: 2.3315s
# EPOCH[278/320] ('loss0.00323-|Sample:0.02|', 0.0032338679768145083)
# Train time: 2.3986s
# EPOCH[279/320] ('loss0.00362-|Sample:0.01|', 0.0036192161403596403)
# Train time: 2.3708s
# EPOCH[280/320] ('loss0.00347-|Sample:0.01|', 0.0034684305265545844)
# Train time: 2.2793s
# EPOCH[281/320] ('loss0.00321-|Sample:0.00|', 0.0032123034726828335)
# Train time: 2.3306s
# EPOCH[282/320] ('loss0.00307-|Sample:0.02|', 0.0030740906950086355)
# Train time: 2.2814s
# EPOCH[283/320] ('loss0.00343-|Sample:0.02|', 0.0034302547574043274)
# Train time: 2.2867s
# EPOCH[284/320] ('loss0.00335-|Sample:0.00|', 0.0033489225897938013)
# Train time: 2.2834s
# EPOCH[285/320] ('loss0.00372-|Sample:0.02|', 0.003724125558510423)
# Train time: 2.2639s
# EPOCH[286/320] ('loss0.00320-|Sample:0.01|', 0.0031951614003628494)
# Train time: 2.2776s
# EPOCH[287/320] ('loss0.00327-|Sample:0.02|', 0.0032695341203361748)
# Train time: 2.2819s
# EPOCH[288/320] ('loss0.00338-|Sample:0.00|', 0.0033834555838257075)
# Train time: 2.2873s
# EPOCH[289/320] ('loss0.00342-|Sample:0.02|', 0.003418881269171834)
# Train time: 2.3253s
# EPOCH[290/320] ('loss0.00360-|Sample:0.00|', 0.0036025271378457547)
# Train time: 2.2725s
# EPOCH[291/320] ('loss0.00324-|Sample:0.00|', 0.00323732303455472)
# Train time: 2.2717s
# EPOCH[292/320] ('loss0.00331-|Sample:0.00|', 0.0033095697406679394)
# Train time: 2.2756s
# EPOCH[293/320] ('loss0.00342-|Sample:0.02|', 0.0034197396971285344)
# Train time: 2.2584s
# EPOCH[294/320] ('loss0.00330-|Sample:0.02|', 0.0033011805359274148)
# Train time: 2.2751s
# EPOCH[295/320] ('loss0.00302-|Sample:0.02|', 0.0030166059359908104)
# Train time: 2.2670s
# EPOCH[296/320] ('loss0.00336-|Sample:0.00|', 0.0033604226633906363)
# Train time: 2.2715s
# EPOCH[297/320] ('loss0.00339-|Sample:0.02|', 0.0033906109631061552)
# Train time: 2.2759s
# EPOCH[298/320] ('loss0.00329-|Sample:0.00|', 0.0032932497933506966)
# Train time: 2.2728s
# EPOCH[299/320] ('loss0.00347-|Sample:0.02|', 0.0034691625274717807)
# Train time: 2.2665s
# EPOCH[300/320] ('loss0.00312-|Sample:0.00|', 0.0031247827783226967)
# Train time: 2.2890s
# EPOCH[301/320] ('loss0.00331-|Sample:0.02|', 0.003306949641555548)
# Train time: 2.3294s
# EPOCH[302/320] ('loss0.00356-|Sample:0.02|', 0.0035554572846740484)
# Train time: 2.2917s
# EPOCH[303/320] ('loss0.00358-|Sample:0.01|', 0.003578727496787906)
# Train time: 2.3024s
# EPOCH[304/320] ('loss0.00323-|Sample:0.01|', 0.003233962347730994)
# Train time: 2.3001s
# EPOCH[305/320] ('loss0.00350-|Sample:0.01|', 0.00349693201482296)
# Train time: 2.2954s
# EPOCH[306/320] ('loss0.00331-|Sample:0.02|', 0.0033129550144076346)
# Train time: 2.2859s
# EPOCH[307/320] ('loss0.00315-|Sample:0.00|', 0.0031513834092766046)
# Train time: 2.2903s
# EPOCH[308/320] ('loss0.00307-|Sample:0.02|', 0.003073719721287489)
# Train time: 2.2898s
# EPOCH[309/320] ('loss0.00323-|Sample:0.02|', 0.003226632373407483)
# Train time: 2.2898s
# EPOCH[310/320] ('loss0.00345-|Sample:0.00|', 0.0034477727208286524)
# Train time: 2.2879s
# EPOCH[311/320] ('loss0.00321-|Sample:0.02|', 0.0032109840400516986)
# Train time: 2.2914s
# EPOCH[312/320] ('loss0.00331-|Sample:0.02|', 0.0033057639282196762)
# Train time: 2.2885s
# EPOCH[313/320] ('loss0.00331-|Sample:0.00|', 0.003311442928388715)
# Train time: 2.2917s
# EPOCH[314/320] ('loss0.00331-|Sample:0.00|', 0.0033079103846102953)
# Train time: 2.2924s
# EPOCH[315/320] ('loss0.00348-|Sample:0.00|', 0.0034819067362695934)
# Train time: 2.2935s
# EPOCH[316/320] ('loss0.00320-|Sample:0.02|', 0.003196165394037962)
# Train time: 2.3030s
# EPOCH[317/320] ('loss0.00309-|Sample:0.02|', 0.0030873527843505145)
# Train time: 2.2893s
# EPOCH[318/320] ('loss0.00314-|Sample:0.01|', 0.0031429284159094095)
# Train time: 2.2869s
# EPOCH[319/320] ('loss0.00325-|Sample:0.00|', 0.0032472630869597196)
# Train time: 2.2763s
# EPOCH[320/320] ('loss0.00299-|Sample:0.00|', 0.0029930427111685277)
# Inference time: 1.9638s
# {'precision': array([0.]), 'recall': array([0.]), 'ndcg': array([0.])}
# Train time: 2.2899s
# EPOCH[321/320] ('loss0.00320-|Sample:0.02|', 0.003196337390691042)

# %% [markdown]
# ## SSCF

# %%
os._exit(00)

# %%
import os
ROOT_PATH = os.getcwd()
RELATIVE_SSCF_PATH = "./SSCF/sscf"

# %%
# Root 작업 경로로 변경
os.chdir(ROOT_PATH)

# 현재 작업 경로 출력
print("현재 작업 경로:", os.getcwd())

# 상대 경로를 절대 경로로 변환
absolute_path = os.path.abspath(RELATIVE_SSCF_PATH)

# 작업 경로 변경
os.chdir(absolute_path)

# 변경된 작업 경로 출력
print("변경된 작업 경로:", os.getcwd())
# Out:
# 현재 작업 경로: C:\Users\medici\Dacon_Job-Recommendation-System
# 변경된 작업 경로: C:\Users\medici\Dacon_Job-Recommendation-System\SSCF\sscf

# %%
# %run main.py --dataset="JOB" --test="test" --gamma=0.2 --similarity=”pearson"
# Out:
# [gamma] '0.2', [similarity] '”pearson'
#
# reading data...
# measuring similarity of users...
# measuring user-based recommendations...
# measuring similarity of items...
# measuring item-based recommendations...
# measuring final model recommendations...
# measuring performance of final model...
#
# [final model]
# recall@20: 0.00112
#
# --------------------------------------------------------------------------------
# Total Time: 20.50 seconds
